# %%
import pandas as pd
import matplotlib.pyplot as plt
from statsmodels.graphics.tsaplots import plot_acf
from statsmodels.graphics.tsaplots import plot_pacf

# %%
#Loading dataset
train = pd.read_csv("../Datasets/train.csv")    #train dataset

# %%
target = train['target']

# %%
plot_acf(target)
plt.show()

# %%
plot_pacf(target)
plt.show()
# Out:
# /home/mayank/anaconda3/lib/python3.7/site-packages/statsmodels/regression/linear_model.py:1283: RuntimeWarning: invalid value encountered in sqrt
#   return rho, np.sqrt(sigmasq)

# %%
#As can be seen the acf and pacf have low values indicating infinitesimal correlation if any between the rows.
